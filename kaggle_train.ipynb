# %%
# !git clone https://github.com/12somyasahu/arc-lite.git
# %cd arc-lite
# !pip install -q torch torchvision wandb fastapi uvicorn requests numba matplotlib

# %%
import os
from kaggle_secrets import UserSecretsClient
secrets = UserSecretsClient()
os.environ['WANDB_API_KEY'] = secrets.get_secret('WANDB_API_KEY')
os.environ['WANDB_MODE'] = 'online'
os.environ['PYTHONPATH'] = '/kaggle/working/arc-lite'

# %%
# !python src/data/download.py

# %%
# !python scripts/train.py --max_steps 20000 --log_every 50 --eval_every 500 --save_every 500
